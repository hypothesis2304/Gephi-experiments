# %%
import pandas as pd

# %%
df = pd.read_csv('/home/prannoys21/Downloads/network assignment/images_assign4/forced_atlas_2/data.csv')

# %%
df.head()
# Out:
#      Id  Label                                            timeset    1   2  \
# 0  1026   1026  <[1246290100000.0, 1246309000000.0]; [12463414...   94  28
# 1  1029   1029  <[1246353100000.0, 1246354000000.0]; [12463594...   61  28
# 2  1032   1032  <[1246260400000.0, 1246268500000.0]; [12462883...  108  45
# 3  1033   1033  <[1246281100000.0, 1246297300000.0]; [12463117...   89  60
# 4  1035   1035               <[1246442200000.0, 1246468300000.0]>   29  44
#
#      3                                                  4  \
# 0  151  <[1246290100000.0, 1246291000000.0, 1]; [12462...
# 1  344  <[1246353100000.0, 1246354000000.0, 1]; [12463...
# 2  297  <[1246260400000.0, 1246261300000.0, 5]; [12462...
# 3  649  <[1246281100000.0, 1246282000000.0, 2]; [12462...
# 4  265  <[1246442200000.0, 1246443100000.0, 3]; [12464...
#
#                                                    5  modularity_class  \
# 0  <[1246290100000.0, 1246291000000.0, 2]; [12462...                12
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 17 columns):
# Id                            113 non-null int64
# Label                         113 non-null int64
# timeset                       113 non-null object
# 1                             113 non-null int64
# 2                             113 non-null int64
# 3                             113 non-null int64
# 4                             113 non-null object
# 5                             113 non-null object
# modularity_class              113 non-null int64
# weighted indegree             113 non-null int64
# weighted outdegree            113 non-null int64
# Weighted Degree               113 non-null int64
# Eccentricity                  113 non-null int64
# closnesscentrality            113 non-null float64
# harmonicclosnesscentrality    113 non-null float64
# betweenesscentrality          113 non-null float64
# eigencentrality               113 non-null float64
# ...

# %%
df.describe()
# Out:
#                 Id        Label           1           2            3  \
# count   113.000000   113.000000  113.000000  113.000000   113.000000
# mean   1141.433628  1141.433628   91.504425   38.283186   421.911504
# std      78.869566    78.869566   34.354279   18.382576   597.324310
# min    1026.000000  1026.000000    4.000000    1.000000     2.000000
# 25%    1085.000000  1085.000000   70.000000   25.000000   115.000000
# 50%    1131.000000  1131.000000   98.000000   35.000000   285.000000
# 75%    1187.000000  1187.000000  114.000000   48.000000   535.000000
# max    1360.000000  1360.000000  206.000000   97.000000  4672.000000
#
#        modularity_class  weighted indegree  weighted outdegree  \
# count        113.000000         113.000000          113.000000
# mean           8.522124          41.159292           41.159292
# std            4.690601          38.350723           37.575297
# min            0.000000           0.000000            0.000000
# ...

# %% [markdown]
# # Though we can see the average values in above table, lets individually calculate them

# %%
df['weighted indegree'].mean()
# Out:
# 41.15929203539823

# %%
df['Weighted Degree'].mean()
# Out:
# 82.31858407079646

# %%
df['modularity_class'].mean()
# Out:
# 8.52212389380531

# %%
df['betweenesscentrality'].mean()
# Out:
# 33.5044247964602

# %%
df['eigencentrality'].mean()
# Out:
# 0.1163550353982301
